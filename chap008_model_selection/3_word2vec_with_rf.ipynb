# %% [markdown]
# <p style="color:#153462;
#           font-weight: bold;
#           font-size: 30px;
#           font-family: Gill Sans, sans-serif;
#           text-align: center;">
#           Building RF model with Word2Vec</p>

# %% [markdown]
# ### Importing Required Modules

# %%
import pandas as pd
import gensim
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %% [markdown]
# ### Reading Data

# %%
# Reading data from pickle file which preserved the list data type
X_train = pd.read_pickle("data/X_train.pkl")
X_test = pd.read_pickle("data/X_test.pkl")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")

# %%
X_train[0]
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'got',
#  'amore',
#  'wat']

# %% [markdown]
# ### Vectorizing the Data

# %%
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100, # 'size' of the vector,
                                   window=3,        #'window' is the maximum distance between the current and predicted word 
                                                    # within a sentence.
                                   min_count=2      #'min_count' ignore all words with total frequency lower than this
                                  )

# %%
w2v_model.wv.index_to_key[:10]
# Out:
# ['u', 'call', '2', 'im', 'ur', 'get', 'free', 'å', 'go', '4']

# %%
words = w2v_model.wv.index_to_key
X_train_vect = [np.array([w2v_model.wv[i]
                          for i in ls
                          if i in w2v_model.wv.index_to_key])
                for ls in X_train]
X_test_vect = [np.array([w2v_model.wv[i]
                          for i in ls
                          if i in w2v_model.wv.index_to_key])
                for ls in X_test]

# %%
X_train_vect_avg = []
for vect in X_train_vect:
    if len(vect) != 0:
        X_train_vect_avg.append(vect.mean(axis=0))
    else:
        X_train_vect_avg.append(np.zeros(100))

        
X_test_vect_avg = []
for vect in X_test_vect:
    if len(vect) != 0:
        X_test_vect_avg.append(vect.mean(axis=0))
    else:
        X_test_vect_avg.append(np.zeros(100))

# %%
len(X_train_vect_avg), len(X_test_vect_avg)
# Out:
# (4457, 1115)

# %%
X_train_vect[0]
# Out:
# array([[-6.69803545e-02,  1.02860115e-01,  2.17516553e-02,
#          1.32015173e-03, -4.82793525e-03, -1.28149644e-01,
#          3.31592038e-02,  1.59097254e-01, -4.87229973e-02,
#         -3.01212296e-02, -4.52283174e-02, -1.08836077e-01,
#         -6.65801065e-03,  2.22745612e-02, -7.72668427e-05,
#         -5.98038025e-02,  1.78443659e-02, -7.70218223e-02,
#         -1.06462808e-02, -1.52409285e-01,  5.72751053e-02,
#          6.41649291e-02,  5.13491295e-02, -2.54002586e-02,
#         -3.22458297e-02,  1.34149659e-02, -6.22793287e-02,
#         -6.78288266e-02, -6.49586767e-02,  1.61025785e-02,
#          9.89502668e-02,  4.73650694e-02,  4.30650897e-02,
#         -4.59256545e-02, -5.29546700e-02,  1.03328601e-01,
#         -7.69436266e-03, -6.29767925e-02, -4.39025573e-02,
#         -1.41546652e-01,  2.59117968e-02, -7.69384876e-02,
#         -2.63931360e-02,  2.83053168e-03,  6.33048639e-02,
#         -5.07848114e-02, -7.55221620e-02, -1.57285575e-02,
#          2.91331913e-02,  6.29634783e-02,  5.65952919e-02,
#         -5.96926697e-02, -2.35500820e-02, -1.11235855e-02,
#         -4.95317765e-02,  3.81649360e-02,  6.16216958e-02,
#          4.39550495e-03, -7.06078857e-02,  6.01441227e-03,
#          3.79640684e-02,  2.37016566e-02, -1.54582923e-02,
#         -3.03155202e-02, -8.37494507e-02,  5.19175939e-02,
#          2.82019358e-02,  4.41014692e-02, -1.07085392e-01,
#          9.37637538e-02, -6.34240881e-02,  4.15942967e-02,
#          6.41653091e-02, -2.22645905e-02,  6.87856451e-02,
#          2.75716428e-02,  2.78012943e-03, -8.04616418e-03,
#         -6.40032217e-02,  3.77544425e-02, -5.58731668e-02,
#          7.71251461e-03, -9.88331884e-02,  1.10252447e-01,
#         -2.30696034e-02, -1.78347677e-02, -2.65220758e-02,
#          9.09507051e-02,  7.73174316e-02,  2.94399578e-02,
#          9.35024992e-02,  6.00126572e-02,  2.25961246e-02,
#          2.13251915e-02,  1.55110210e-01,  5.94165139e-02,
#          4.61611487e-02, -6.21142387e-02,  7.92737026e-03,
#          6.42356509e-03],
#        [-1.86505049e-01,  2.66337097e-01,  5.00043221e-02,
#         -2.26077493e-02, -3.02008986e-02, -3.21223795e-01,
#          8.36727545e-02,  4.40389484e-01, -1.12972543e-01,
#         -9.54465419e-02, -1.47047311e-01, -2.76370198e-01,
#         -2.22950298e-02,  7.09324777e-02,  2.28690784e-02,
#         -1.55895069e-01,  2.38776486e-02, -2.18689784e-01,
#         -2.60473462e-03, -4.23754662e-01,  1.26652464e-01,
#          1.75134271e-01,  1.33165613e-01, -4.20413278e-02,
#         -9.25736800e-02,  3.54565494e-02, -1.43463686e-01,
#         -1.94771439e-01, -1.50969893e-01,  2.18143500e-02,
#          2.42364556e-01,  9.49399471e-02,  7.88829699e-02,
#         -1.35862082e-01, -1.24853976e-01,  2.73573667e-01,
#          1.32499402e-03, -1.46566704e-01, -1.26437962e-01,
#         -3.95663142e-01,  5.59243821e-02, -1.95495263e-01,
#         -6.39523566e-02,  6.89953379e-03,  1.85777143e-01,
#         -1.52333692e-01, -2.00221241e-01, -5.44072725e-02,
#          8.39525312e-02,  1.44689843e-01,  1.21552862e-01,
#         -1.23255439e-01, -5.01963496e-02, -4.92932573e-02,
#         -1.08340807e-01,  9.08557251e-02,  1.63044587e-01,
#         -9.16998833e-03, -1.64369002e-01,  1.62718501e-02,
#          7.87854046e-02,  6.00652248e-02, -6.29522353e-02,
#         -5.92410415e-02, -2.21869692e-01,  1.46378562e-01,
#          5.71204945e-02,  1.20595895e-01, -2.59043187e-01,
#          2.64697850e-01, -1.63120896e-01,  1.24024585e-01,
#          1.74761727e-01, -5.60092553e-02,  1.97930574e-01,
#          8.92851129e-02,  3.32614630e-02, -1.56735610e-02,
#         -2.02250540e-01,  1.13362521e-01, -1.50051013e-01,
#         -9.39333159e-03, -2.65097111e-01,  2.91847885e-01,
#         -5.72512448e-02, -4.19457890e-02, -4.53417599e-02,
#          2.36939445e-01,  2.17765495e-01,  7.25737140e-02,
#          2.27087110e-01,  1.68763921e-01,  6.22320548e-02,
#          8.03601146e-02,  4.13630426e-01,  1.50427774e-01,
#          1.10142939e-01, -1.86478674e-01,  4.40446697e-02,
#          1.78452302e-02],
#        [-7.40746781e-02,  9.34812352e-02,  2.14476474e-02,
#         -9.42743942e-03, -1.18099079e-02, -1.23999439e-01,
#          3.71734500e-02,  1.69349164e-01, -3.77082415e-02,
#         -4.05226387e-02, -4.40399423e-02, -1.06639571e-01,
#         -5.42372325e-03,  2.20202040e-02,  1.21555002e-02,
#         -4.86030430e-02,  5.87734394e-03, -8.08786303e-02,
#          7.97910150e-03, -1.65966108e-01,  4.84496690e-02,
#          7.57033974e-02,  5.32344095e-02, -1.71865430e-02,
#         -2.47218534e-02,  7.03554694e-03, -4.80674617e-02,
#         -8.05499852e-02, -6.65243641e-02,  6.82998076e-03,
#          9.68320444e-02,  4.67809886e-02,  2.84500830e-02,
#         -4.98586632e-02, -3.82779576e-02,  1.12996332e-01,
#          5.92364231e-03, -6.31967485e-02, -4.37820144e-02,
#         -1.51193127e-01,  1.13312928e-02, -7.36568496e-02,
#         -1.82217751e-02,  6.29404793e-03,  7.21153319e-02,
#         -6.88409731e-02, -6.47784546e-02, -1.31295547e-02,
#          2.06629336e-02,  5.30886389e-02,  4.41789366e-02,
#         -5.34909181e-02, -2.75677238e-02, -5.24243060e-03,
#         -3.34746391e-02,  2.88533084e-02,  5.48333861e-02,
#          6.85204845e-03, -6.35571256e-02,  6.80873543e-03,
#          3.39513421e-02,  2.12569255e-02, -2.57736575e-02,
#         -2.73969248e-02, -8.75927061e-02,  5.35517596e-02,
#          2.74600554e-02,  3.52410562e-02, -8.98374915e-02,
#          1.00615285e-01, -6.55472875e-02,  5.86033650e-02,
#          6.90239444e-02, -2.26108953e-02,  6.68224469e-02,
#          4.02519442e-02,  7.73924403e-03, -7.44677661e-03,
#         -6.95540160e-02,  4.35987264e-02, -5.89078926e-02,
#          7.60389492e-04, -9.59594697e-02,  1.01355486e-01,
#         -1.20421425e-02, -5.19385841e-03, -6.53398922e-03,
#          8.50803107e-02,  7.49127492e-02,  2.92969495e-02,
#          8.56513679e-02,  6.76997155e-02,  2.22334135e-02,
#          2.47255750e-02,  1.45667344e-01,  5.75678088e-02,
#          4.58935462e-02, -6.45855069e-02,  1.10481735e-02,
#         -5.57558471e-03],
#        [-1.27841413e-01,  1.97139308e-01,  3.31911966e-02,
#         -1.91989429e-02, -1.57540906e-02, -2.48166651e-01,
#          6.41610473e-02,  3.27559590e-01, -8.04236755e-02,
#         -7.60089383e-02, -1.00614518e-01, -2.01845706e-01,
#         -4.03729919e-03,  4.82149050e-02,  9.18284524e-03,
#         -1.10488273e-01,  2.18825974e-02, -1.56188399e-01,
#          1.10646721e-03, -3.11644733e-01,  1.02473676e-01,
#          1.27497450e-01,  1.07510030e-01, -4.41424809e-02,
#         -5.52574620e-02,  2.09663026e-02, -1.04919501e-01,
#         -1.38444141e-01, -1.25205487e-01,  1.07016340e-02,
#          1.74949914e-01,  7.18818456e-02,  7.65974224e-02,
#         -1.03456371e-01, -9.09103602e-02,  2.10396364e-01,
#          2.29158951e-03, -1.17143221e-01, -9.32874605e-02,
#         -2.80850947e-01,  4.91290540e-02, -1.55705899e-01,
#         -4.60690930e-02,  1.33274570e-02,  1.34067357e-01,
#         -1.26709327e-01, -1.45307407e-01, -5.08217774e-02,
#          5.93157262e-02,  1.00158490e-01,  1.01201065e-01,
#         -1.01897210e-01, -3.41300070e-02, -3.07390522e-02,
#         -8.66251960e-02,  6.34131059e-02,  1.15472041e-01,
#         -1.02767674e-02, -1.24291815e-01,  1.79687832e-02,
#          6.24332242e-02,  3.20333689e-02, -4.58602607e-02,
#         -4.54100296e-02, -1.51487067e-01,  1.19647458e-01,
#          5.23644798e-02,  8.77971947e-02, -2.01514557e-01,
#          1.93015993e-01, -1.27843723e-01,  9.34404507e-02,
#          1.37009159e-01, -3.62514965e-02,  1.39067441e-01,
#          8.25742781e-02,  2.45805532e-02, -1.17986780e-02,
#         -1.53202817e-01,  9.01623592e-02, -1.13671653e-01,
#          6.33596210e-03, -1.97037533e-01,  2.17414811e-01,
#         -4.88930494e-02, -3.00619826e-02, -3.71171087e-02,
#          1.72478154e-01,  1.52054429e-01,  5.41989915e-02,
#          1.79022983e-01,  1.33022636e-01,  4.06950638e-02,
#          4.71276678e-02,  3.13817263e-01,  1.18192315e-01,
#          8.11191574e-02, -1.31871283e-01,  3.47978212e-02,
#          4.58611315e-03],
#        [-8.14901316e-04,  1.31866066e-02, -3.31849884e-03,
#         -1.01102181e-02, -7.89278373e-03, -4.64683538e-03,
#          4.96313302e-03,  1.90986339e-02, -1.64658320e-03,
#          3.09702056e-03, -1.24201356e-02, -9.71002784e-03,
#          8.36167205e-03,  7.53301010e-03, -2.22608075e-03,
#          5.54321054e-03,  8.83162662e-04, -1.56550873e-02,
#          4.39169293e-04, -7.99867138e-03,  1.00755533e-02,
#          1.51555345e-03,  4.97030141e-03, -8.85151606e-03,
#         -7.62843818e-04,  6.58043427e-04, -3.71208857e-03,
#         -7.83784315e-03,  5.80097968e-03,  4.30900790e-03,
#          6.39678817e-03,  3.56548629e-03, -5.05537353e-03,
#         -1.34127438e-02, -1.01791974e-02,  1.76598813e-04,
#         -3.58763523e-03, -5.08482056e-03, -9.31036845e-03,
#         -4.72981762e-03, -4.10285685e-03, -1.30966930e-02,
#          6.63735857e-03, -7.74305430e-04, -6.44377200e-04,
#         -1.37487501e-02, -4.20886150e-04,  4.98489290e-03,
#          4.27937508e-03,  1.31638842e-02, -6.20689895e-03,
#         -2.12082104e-03, -7.91069958e-03,  4.26936848e-03,
#          2.73966987e-04, -4.12719510e-03,  6.56978693e-03,
#          8.55675433e-04, -4.32843249e-03,  9.40517464e-04,
#          6.95024524e-03, -1.42598606e-03,  2.53563304e-03,
#          5.63808717e-03, -1.18050436e-02, -5.33390185e-03,
#         -3.79478862e-03,  8.20449647e-03, -1.13725495e-02,
#          8.86882655e-03,  1.00843550e-03, -1.28643715e-03,
#          3.29871057e-03, -8.19625892e-03,  1.09055107e-02,
#         -4.73891618e-03,  2.22104206e-03, -6.17709802e-03,
#         -4.70021274e-03,  8.48109461e-03, -1.98630709e-03,
#          7.91497622e-03,  5.85546833e-04,  3.57491779e-03,
#          1.83189433e-04,  5.93283726e-03, -8.48960225e-03,
#          3.48473969e-03, -3.93038010e-03, -6.33316347e-03,
#          1.27382698e-02,  1.41579937e-02,  1.01090327e-03,
#          6.70726178e-04,  1.83232576e-02, -6.29371498e-04,
#         -5.86275244e-03, -1.31708216e-02,  3.78891057e-03,
#         -4.06164350e-03],
#        [-8.23401904e-04,  1.60008874e-02, -8.18238128e-03,
#         -1.45123829e-03, -1.47884723e-03, -1.01917963e-02,
#         -6.03667274e-03,  7.53731607e-03, -1.35347946e-02,
#          5.22409892e-03, -8.63487460e-03, -3.99729516e-03,
#          3.42578534e-03,  4.86061722e-03,  1.01798130e-02,
#         -6.69602246e-04, -2.76402966e-03, -1.22291790e-02,
#         -3.29236570e-03, -1.32799959e-02,  4.70705377e-03,
#         -2.17046449e-03,  7.63512170e-03, -5.09011513e-03,
#         -2.83921603e-04, -7.10393069e-03, -1.13320572e-03,
#         -1.50207989e-02, -5.72287245e-04,  3.87689820e-03,
#          7.19651626e-03,  6.53944165e-03, -6.21432625e-03,
#         -6.82240492e-03, -6.94415485e-03,  5.57946414e-03,
#         -3.32084042e-03, -8.51902645e-03, -2.16709147e-03,
#         -1.70048159e-02,  3.59827257e-03, -9.25940461e-03,
#         -6.78059459e-03, -6.68832194e-03,  3.84062412e-03,
#         -8.10557511e-03, -1.29117491e-02, -5.48846368e-03,
#          1.24084046e-02,  2.29366147e-03, -4.11121128e-03,
#         -8.84532288e-04, -1.13228504e-02, -9.20460746e-03,
#         -1.33676995e-02,  1.07266223e-02,  1.52534703e-02,
#         -4.05101711e-03, -1.27329215e-04, -1.03868661e-03,
#         -1.39950297e-03, -4.90959641e-03, -2.65723304e-03,
#          1.80878036e-03, -9.71155893e-03,  1.42944641e-02,
#          6.90999394e-03,  4.06215526e-03, -1.47934202e-02,
#          8.03520321e-04, -9.89156030e-03,  7.09774578e-03,
#          1.61556806e-02, -7.93519523e-03,  1.58839561e-02,
#         -4.51607164e-03, -9.07836854e-03,  6.95728371e-03,
#         -8.73155240e-03, -3.29237408e-03, -7.35872472e-03,
#          6.04491169e-03, -1.89789291e-02,  1.52556868e-02,
#          3.41189024e-03, -9.36494675e-03,  2.63604964e-03,
#          5.30412886e-03,  1.05918674e-02, -4.94929403e-03,
#          1.51338624e-02,  3.61621170e-03, -6.49039960e-03,
#          6.28566660e-04,  1.78578813e-02,  8.12025741e-03,
#         -2.82794749e-03, -2.77989125e-03, -6.25446485e-03,
#         -6.57216366e-03]], dtype=float32)

# %%
X_test_vect_avg[0]
# Out:
# array([-0.12942263,  0.17597687,  0.03171194, -0.0127439 , -0.02371626,
#        -0.2331    ,  0.06882467,  0.3134724 , -0.08379792, -0.07236389,
#        -0.09798687, -0.19297709, -0.01566335,  0.04329884,  0.00925785,
#        -0.10843015,  0.02198656, -0.15612675, -0.00080967, -0.29926273,
#         0.09199122,  0.12773265,  0.0930573 , -0.03509374, -0.05741769,
#         0.02295233, -0.09939837, -0.13883917, -0.10759931,  0.01537984,
#         0.17733431,  0.07516875,  0.06037512, -0.09840945, -0.08572774,
#         0.2039517 , -0.00238057, -0.11347193, -0.09018958, -0.28189018,
#         0.03971195, -0.14564332, -0.03493845,  0.01026732,  0.14099069,
#        -0.11275298, -0.13549386, -0.04071792,  0.05404897,  0.10176396,
#         0.09356767, -0.0922479 , -0.03853101, -0.02643051, -0.07900909,
#         0.06065756,  0.10860988, -0.00364809, -0.11652074,  0.01662985,
#         0.06663826,  0.04090013, -0.03826622, -0.03890239, -0.15443702,
#         0.11308748,  0.04518036,  0.08523154, -0.18573488,  0.1873358 ,
#        -0.11992348,  0.0956661 ,  0.13626404, -0.036108  ,  0.14621116,
#         0.06648132,  0.01740314, -0.0141118 , -0.14150797,  0.0751267 ,
#        -0.1029634 , -0.00217882, -0.18945809,  0.20559025, -0.03441174,
#        -0.03018264, -0.03436232,  0.15965569,  0.14769764,  0.06221365,
#         0.1674782 ,  0.11744075,  0.04671296,  0.05976249,  0.29580596,
#         0.10624862,  0.08273222, -0.13856046,  0.03176657,  0.0077866 ],
#       dtype=float32)

# %% [markdown]
# ### Building Random Forest with Word2Vec

# %%
rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect_avg, y_train.values.ravel())

# %%
y_pred = rf_model.predict(X_test_vect_avg)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       976
#            1       0.99      0.49      0.65       139
#
#     accuracy                           0.94      1115
#    macro avg       0.96      0.74      0.81      1115
# weighted avg       0.94      0.94      0.93      1115
